# %%
#Install pandas profile package
! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
#CLUE datasets
#======================================================
import pandas as pd
import pandas_profiling

#Residential dwellings data
resident = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SIT782/CLUE/Residential_dwellings.csv')
resident.info()

#profiling the data
report = resident.profile_report(
    sort=None, html={"style": {"full_width": True}}, progress_bar=False
)
report
#report.to_file('Residential_dwellings_EDA.html')

# %%
#Employment data
employment = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SIT782/CLUE/Employment_by_block_by_CLUE_industry.csv')
employment.info()

#profiling the data
report = employment.profile_report(
    sort=None, html={"style": {"full_width": True}}, progress_bar=False
)
report
#report.to_file('Employment_EDA.html')

# %%
#Off-street parking data
parking = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SIT782/CLUE/Off-street_car_parks_with_capacity_and_type.csv')
parking.info()

#profiling the data
report = parking.profile_report(
    sort=None, html={"style": {"full_width": True}}, progress_bar=False
)
report
#report.to_file('OffSteet_Parking_EDA.html')

# %%
#Check some duplication values in off-street parking data
parking[parking.duplicated(keep=False)]
parking[(parking['Property ID']==105746)&(parking['Census year']==2006)]

# %%
#Check the null values in [Totla employment in block]
employment[pd.isnull(employment['Total employment in block'])]

# %%
#PDA datasets
#===============================================================================================================

#Pedestrian_hourly_count
pedestrian_count = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SIT782/PDA/Pedestrian_Counting.csv',low_memory=True)
print('Attributes and datatypes')
print(pedestrian_count.info())
print('\n')

#profiling the data
#report = pedestrian_count.profile_report(sort=None, html={"style": {"full_width": True}}, progress_bar=False)
#report.to_file('Pedestrian_Count_EDA.html')

#Check for missing values
print('NULL values?')
print(pedestrian_count.isnull().sum())
print('\n')

#Check douplicate values
print('Duplicated values in any attribute?')
print(len(pedestrian_count[pedestrian_count.duplicated(keep=False)]))
print('\n')

#Check for error in data values
print('Possible mispelling or errors in data values?')
for column in pedestrian_count.columns:
  unique_values = pedestrian_count[column].unique()
  if len(unique_values) <= 50:
    print(column, unique_values)

#pedestrian_count.head()
# Out:
# Attributes and datatypes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3962835 entries, 0 to 3962834
# Data columns (total 10 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   ID             int64
#  1   Date_Time      object
#  2   Year           int64
#  3   Month          object
#  4   Mdate          int64
#  5   Day            object
#  6   Time           int64
#  7   Sensor_ID      int64
#  8   Sensor_Name    object
#  9   Hourly_Counts  int64
# dtypes: int64(6), object(4)
# memory usage: 302.3+ MB
# None
#
#
# NULL values?
# ID               0
# Date_Time        0
# Year             0
# Month            0
# Mdate            0
# Day              0
# Time             0
# Sensor_ID        0
# Sensor_Name      0
# Hourly_Counts    0
# dtype: int64
#
#
# Duplicated values in any attribute?
# 0
#
#
# Possible mispelling or errors in data values?
# Year [2019 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2020 2021]
# ...

# %%
#Pedestrian sensor location
pedestrian_sensor_locations = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SIT782/PDA/Pedestrian_Sensor_Locations.csv')
pedestrian_sensor_locations.info()

#profiling the data
report = pedestrian_sensor_locations.profile_report(
    sort=None, html={"style": {"full_width": True}}, progress_bar=False
)
report
#report.to_file('Pedestrian_Sensor_Locations_EDA.html')

# %%
#Business Establishments
business_establishments = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SIT782/CLUE/Business_establishments_per_block_by_CLUE_industry.csv')
business_establishments.info()

#profiling the data
report = business_establishments.profile_report(
    sort=None, html={"style": {"full_width": True}}, progress_bar=False
)
report
#report.to_file('business_establishments_EDA.html')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11182 entries, 0 to 11181
# Data columns (total 24 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Census year                                 11182 non-null  int64
#  1   Block ID                                    11182 non-null  int64
#  2   CLUE small area                             11182 non-null  object
#  3   Accommodation                               11182 non-null  int64
#  4   Admin and Support Services                  11182 non-null  int64
#  5   Agriculture and Mining                      11182 non-null  int64
#  6   Arts and Recreation Services                11182 non-null  int64
#  7   Business Services                           11182 non-null  int64
#  8   Construction                                11182 non-null  int64
#  9   Education and Training                      11182 non-null  int64
# ...

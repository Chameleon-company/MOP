# %%
import os
import time
from datetime import datetime
import pandas as pd
from sodapy import Socrata

## based on 
# https://github.com/xmunoz/sodapy/blob/master/examples/basic_queries.ipynb
# https://github.com/xmunoz/sodapy
# /COM-Team_Project/deakin.py

## useful info from
# https://socratadiscovery.docs.apiary.io/#

apptoken = os.environ.get("SODAPY_APPTOKEN")
domain = "data.melbourne.vic.gov.au"

client = Socrata(domain, apptoken)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
## 001 ##
# rds = client.datasets()
# datasets_df = pd.DataFrame.from_dict(rds)
# datasets_df.describe().transpose()

# %%
# !export SODAPY_APPTOKEN="wMEkdLbVuXIpLiCFVic1PgiZ3"

# %%
## 002 ##
#fields_abt_datasets = ['resource','classification','metadata','permalink','link','owner','creator','preview_image_url']

## not interested : metadata, link, owner, creator, preview_image_url

## interested ...
# resource -> [1] name [2] id [3] parent_fxf [4] description [5] metadata_updated_at [6] data_updated_at
#  [7] page_views [8] columns_field_name [9] columns_datatype [10] columns_description [11] publication_date
# classification -> [1] domain_tags [2] domain_metadata
# permalink

# %%
## 003 ##
# define function to get interested info from datasets info

def get_interested_df(res):
    rname = []
    rid = []
    rparent_fxf = []
    rdescription = []
    rupdatedAt = []
    rcreatedAt = []
    rmetadata_updated_at = []
    rdata_updated_at = []
    rpage_views = []
    rcolumns_field_name = []
    rcolumns_datatype = []
    rcolumns_description = []
    rpublication_date = []
    cdomain_tags = []
    cdomain_metadata = []
    pl = []

    for ds in res:
        rname.append(ds['resource']['name'])
        rid.append(ds['resource']['id'])
        rparent_fxf.append(ds['resource']['parent_fxf'])
        rdescription.append(ds['resource']['description'])   
        rupdatedAt.append(ds['resource']['updatedAt'])
        rcreatedAt.append(ds['resource']['createdAt'])
        rmetadata_updated_at.append(ds['resource']['metadata_updated_at'])
        rdata_updated_at.append(ds['resource']['data_updated_at'])
        rpage_views.append(ds['resource']['page_views'])
        rcolumns_field_name.append(ds['resource']['columns_field_name'])
        rcolumns_datatype.append(ds['resource']['columns_datatype'])
        rcolumns_description.append(ds['resource']['columns_description'])
        rpublication_date.append(ds['resource']['publication_date'])
        cdomain_tags.append(ds['classification']['domain_tags'])
        cdomain_metadata.append(ds['classification']['domain_metadata'])
        pl.append(ds['permalink'])

    ndf = pd.DataFrame({
        "r.name":rname,
        "r.id":rid,
        "r.parent_fxf":rparent_fxf,
        "r.description":rdescription,
        "r.updatedAt":rupdatedAt,
        "r.createdAt":rcreatedAt,
        "r.metadata_updated_at":rmetadata_updated_at,
        "r.data_updated_at":rdata_updated_at,
        "r.page_views":rpage_views,
        "r.columns_field_name":rcolumns_field_name,
        "r.columns_datatype":rcolumns_datatype,
        "r.columns_description":rcolumns_description,
        "r.publication_date":rpublication_date,
        "c.domain_tags":cdomain_tags,
        "c.domain_metadata":cdomain_metadata,
        "permalink":pl
    })

    ndf["r.metadata_updated_at"] = pd.to_datetime(ndf["r.metadata_updated_at"])
    ndf["r.data_updated_at"] = pd.to_datetime(ndf["r.data_updated_at"])
    ndf["r.publication_date"] = pd.to_datetime(ndf["r.publication_date"])

    return ndf

# %%
## 004 ##
# get interested datasets info and write to csv
rds = client.datasets()
df = get_interested_df(rds)
df.to_csv("com_datasets_info.csv", index=True)  # write to csv

# %%
## 005 ##
# check top 20 most recently updated datasets

df.sort_values(by=["r.updatedAt"],ascending=False).head(20)

# seems there are 11 datasets that update regularly (multiple times within the hour)
# and another 3 probably hourly
# Out:
#                                                 r.name       r.id  \
# 3                        On-street Parking Bay Sensors  vh2v-4nfs
# 14   Street furniture including bollards, bicycle r...  8fgn-5q6t
# 116                                    Stormwater Pits  psq9-yz4x
# 29   Pedestrian Counting System - Past Hour (counts...  d6mv-s43h
# 195                               Soil Sensor Readings  mv4n-8k4v
# 67                        Microclimate Sensor Readings  u4vh-84j8
# 127                      Microclimate Sensor Locations  irqv-hjr4
# 159                   Tactile Ground Surface Indicator  v4zv-yqtp
# 166                          Pumping Station Locations  55z9-zqzu
# 58                                      Public toilets  ru3z-44we
# 2    Trees, with species and dimensions (Urban Forest)  fp38-wiyy
# 11                 On-street Car Park Bay Restrictions  ntht-5rk7
# 152                                       Litter Traps  4spx-8bh5
# 53                                       Fire Hydrants  j4qc-4tib
# 56          On-street Car Parking Meters with Location  vdsi-4gtj
# 212                              Bookable Banner Poles  cm7k-9aj4
# 113  Feature Lighting (including light type, wattag...  4j42-79hg
# 217                              Soil Sensor Locations  dxvp-runr
# 137                          Sign Panels (Non Parking)  fzjr-9nrn
# 78                   City Activities and Planned Works  txcy-uafv
#
#     r.parent_fxf                                      r.description  \
# 3             []  Contains information from in-ground car parkin...
# 14            []  The City of Melbourne owns and maintains vario...
# 116           []  This dataset captures all stormwater pits thro...
# 29            []  <b>Current issue 23/09/2020</b>\nPlease note: ...
# 195           []  This dataset contains historical readings for ...
# 67            []  This dataset contains environmental readings f...
# 127           []  This dataset contains location and location de...
# 159           []  This dataset contains tactile ground surface i...
# 166           []  A pump station is a holding chamber that pumps...
# 58            []  Public toilets known about or operated by the ...
# 2             []  The City of Melbourne maintains more than 70,0...
# 11            []  Each row contains information about the restri...
# 152           []  Litter traps are devices that retain ‘gross po...
# 53            []  This dataset contains all the fire hydrants th...
# 56            []  This dataset shows the location and informatio...
# 212           []  The dataset contains all the banner pole locat...
# 113           []  This dataset contains information such as loca...
# 217           []  This dataset contains the locations of where s...
# 137           []  This dataset contains all the non parking sign...
# 78            []  This dataset contains active and planned activ...
#
#                   r.updatedAt               r.createdAt  \
# 3    2021-07-31T16:35:43.000Z  2017-08-10T04:57:59.000Z
# 14   2021-07-31T16:34:46.000Z  2014-09-09T01:46:26.000Z
# 116  2021-07-31T16:32:13.000Z  2017-11-22T03:42:47.000Z
# 29   2021-07-31T16:32:12.000Z  2018-10-19T03:55:44.000Z
# 195  2021-07-31T16:30:26.000Z  2020-04-01T01:21:18.000Z
# 67   2021-07-31T16:30:18.000Z  2020-06-10T02:26:44.000Z
# 127  2021-07-31T16:30:15.000Z  2020-06-17T22:22:29.000Z
# 159  2021-07-31T16:26:30.000Z  2018-01-16T21:38:53.000Z
# 166  2021-07-31T16:08:03.000Z  2017-11-22T02:52:09.000Z
# 58   2021-07-31T16:07:42.000Z  2016-01-29T03:13:34.000Z
# 2    2021-07-31T16:06:52.000Z  2014-05-26T04:40:31.000Z
# 11   2021-07-31T16:03:40.000Z  2017-09-22T07:59:53.000Z
# 152  2021-07-31T16:02:42.000Z  2017-11-22T23:26:40.000Z
# 53   2021-07-31T16:02:22.000Z  2017-11-23T03:05:21.000Z
# 56   2021-07-31T16:01:37.000Z  2017-08-28T04:54:14.000Z
# 212  2021-07-31T16:01:08.000Z  2018-01-02T02:48:30.000Z
# 113  2021-07-31T16:00:43.000Z  2018-01-02T03:21:26.000Z
# 217  2021-07-31T05:39:59.000Z  2020-03-26T21:23:31.000Z
# 137  2021-07-30T17:14:18.000Z  2018-01-02T03:31:17.000Z
# 78   2021-07-30T16:52:34.000Z  2019-02-18T02:53:42.000Z
#
#         r.metadata_updated_at         r.data_updated_at  \
# 3   2021-07-31 16:35:30+00:00 2021-07-31 16:35:43+00:00
# 14  2021-07-31 16:34:04+00:00 2021-07-31 16:34:46+00:00
# 116 2021-07-31 16:26:39+00:00 2021-07-31 16:32:13+00:00
# 29  2021-07-31 16:32:02+00:00 2021-07-31 16:32:12+00:00
# 195 2021-07-31 16:30:10+00:00 2021-07-31 16:30:26+00:00
# 67  2021-07-31 16:30:05+00:00 2021-07-31 16:30:18+00:00
# 127 2021-07-31 16:30:05+00:00 2021-07-31 16:30:15+00:00
# 159 2021-07-31 16:26:20+00:00 2021-07-31 16:26:30+00:00
# 166 2021-07-31 16:07:52+00:00 2021-07-31 16:08:03+00:00
# 58  2021-07-31 16:07:32+00:00 2021-07-31 16:07:42+00:00
# 2   2021-07-31 16:05:32+00:00 2021-07-31 16:06:52+00:00
# 11  2021-07-31 16:03:27+00:00 2021-07-31 16:03:40+00:00
# 152 2021-07-31 16:02:32+00:00 2021-07-31 16:02:42+00:00
# 53  2021-07-31 16:01:54+00:00 2021-07-31 16:02:22+00:00
# 56  2021-07-31 16:01:26+00:00 2021-07-31 16:01:37+00:00
# 212 2021-07-31 16:00:54+00:00 2021-07-31 16:01:08+00:00
# 113 2021-07-31 16:00:28+00:00 2021-07-31 16:00:43+00:00
# 217 2021-07-31 05:39:49+00:00 2021-07-31 05:39:59+00:00
# 137 2021-07-30 16:52:45+00:00 2021-07-30 17:14:18+00:00
# 78  2021-07-30 16:52:12+00:00 2021-07-30 16:52:34+00:00
#
#                                           r.page_views  \
# 3    {'page_views_last_week': 219, 'page_views_last...
# 14   {'page_views_last_week': 9, 'page_views_last_m...
# 116  {'page_views_last_week': 11, 'page_views_last_...
# 29   {'page_views_last_week': 34, 'page_views_last_...
# 195  {'page_views_last_week': 10, 'page_views_last_...
# 67   {'page_views_last_week': 38, 'page_views_last_...
# 127  {'page_views_last_week': 19, 'page_views_last_...
# 159  {'page_views_last_week': 4, 'page_views_last_m...
# 166  {'page_views_last_week': 6, 'page_views_last_m...
# 58   {'page_views_last_week': 9, 'page_views_last_m...
# 2    {'page_views_last_week': 101, 'page_views_last...
# 11   {'page_views_last_week': 96, 'page_views_last_...
# 152  {'page_views_last_week': 8, 'page_views_last_m...
# 53   {'page_views_last_week': 35, 'page_views_last_...
# 56   {'page_views_last_week': 18, 'page_views_last_...
# 212  {'page_views_last_week': 4, 'page_views_last_m...
# 113  {'page_views_last_week': 5, 'page_views_last_m...
# 217  {'page_views_last_week': 10, 'page_views_last_...
# 137  {'page_views_last_week': 6, 'page_views_last_m...
# 78   {'page_views_last_week': 8, 'page_views_last_m...
#
#                                   r.columns_field_name  \
# 3    [bay_id, st_marker_id, status, location, locat...
# 14   [gis_id, description, asset_class, asset_type,...
# 116  [asset_number, asset_description, construction...
# 29   [date, time, sensor_id, direction_1, direction...
# 195  [id, date, time, site_id, site_name, probe_id,...
# 67   [id, site_id, sensor_id, value, local_time, ty...
# 127  [site_id, description, last_data, latitude, lo...
# 159  [asset_number, description, road_segment, lat,...
# 166  [asset_number, asset_description, number_of_pe...
# 58   [name, female, male, wheelchair, operator, bab...
# 2    [com_id, common_name, scientific_name, genus, ...
# 11   [bayid, deviceid, description1, description2, ...
# 152  [asset_number, asset_description, construct_ma...
# 53   [asset_number, asset_description, maintainer_l...
# 56   [meterid, assetid, barcode, creditcard, tapand...
# 212  [asset_number, asset_description, banner_pole_...
# 113  [asset_number, asset_description, lamp_type_lu...
# 217  [site_name, longitude, latitude, property_name...
# 137  [asset_description, model_descr_lupvalue, mode...
# 78   [small_area, notes, end_date, start_date, loca...
#
#                                     r.columns_datatype  \
# 3    [Number, Text, Text, Point, Text, Text, Text, ...
# 14   [Number, Text, Text, Text, Text, Text, Text, T...
# 116  [Number, Text, Text, Number, Text, Number, Tex...
# 29   [Calendar date, Text, Number, Number, Number, ...
# 195  [Number, Calendar date, Text, Number, Text, Nu...
# 67   [Number, Text, Text, Number, Calendar date, Te...
# 127  [Text, Text, Calendar date, Number, Number, Po...
# 159  [Number, Text, Text, Number, Number, Point, Te...
# 166  [Number, Text, Number, Number, Number, Number,...
# 58    [Text, Text, Text, Text, Text, Text, Text, Text]
# 2    [Number, Text, Text, Text, Text, Number, Numbe...
# 11   [Number, Number, Text, Text, Text, Text, Text,...
# 152  [Number, Text, Text, Text, Text, Text, Text, T...
# 53   [Number, Text, Text, Text, Text, Text, Text, N...
# 56   [Text, Text, Text, Text, Text, Text, Text, Num...
# 212  [Number, Text, Number, Number, Text, Text, Num...
# 113  [Number, Text, Number, Number, Text, Number, N...
# 217        [Text, Number, Number, Text, Number, Point]
# 137  [Text, Text, Text, Text, Number, Number, Numbe...
# 78   [Text, Text, Calendar date, Calendar date, Tex...
#
#                                  r.columns_description  \
# 3    [The unique ID of the parking bay where the pa...
# 14   [, , , , , , , , , Excellent = 5, Poor = 1, , ...
# 116  [The councils unique id of this asset., Descri...
# 29   [Date of the reading, Time of the reading in 2...
# 195  [The unique id of the reading, The date in whi...
# 67   [Unique id for each record in the dataset, Loc...
# 127  [location id , description of the location of ...
# 159  [The councils unique id of this asset., Descri...
# 166  [The councils unique id of this asset., Descri...
# 58                                    [, , , , , , , ]
# 2    [City of Melbourne's unique asset ID, , , , , ...
# 11   [A system generated id tag for each bay object...
# 152  [The councils unique id of this asset., Descri...
# 53   [The councils unique id of this asset., Descri...
# 56   [The meter name that is displayed on the meter...
# 212  [The councils unique id of this asset., Descri...
# 113  [The councils unique id of this asset., Descri...
# 217  [Description of the site location, longitude o...
# 137  [Description of the asset., The type of sign p...
# 78   [CLUE Small Area, Additional information about...
#
#            r.publication_date  \
# 3   2017-09-25 05:01:31+00:00
# 14  2015-10-27 06:00:13+00:00
# 116 2018-02-05 04:36:20+00:00
# 29  2019-01-17 04:46:56+00:00
# 195 2020-04-01 01:43:33+00:00
# 67  2020-06-12 00:02:06+00:00
# 127 2020-06-23 04:59:37+00:00
# 159 2018-02-05 05:55:06+00:00
# 166 2018-02-05 04:54:40+00:00
# 58  2017-09-18 04:19:15+00:00
# 2   2015-11-18 05:01:38+00:00
# 11  2018-05-07 22:07:44+00:00
# 152 2018-02-05 04:47:13+00:00
# 53  2018-02-05 04:59:20+00:00
# 56  2017-09-18 00:11:48+00:00
# 212 2018-02-05 05:47:15+00:00
# 113 2018-02-05 05:17:29+00:00
# 217 2020-10-01 03:14:11+00:00
# 137 2018-02-05 05:11:03+00:00
# 78  2019-04-29 03:21:30+00:00
#
#                                          c.domain_tags  \
# 3    [parking, sensor, near real-time, vacancy, tra...
# 14   [barbeques, bicycle rails, bollards, drinking ...
# 116                        [asset, water, storm, pits]
# 29   [pedestrian, sensors, foot traffic, traffic fl...
# 195  [soil, sensor, moisture, salinity, temperature...
# 67   [sensor, microclimate, environment, air qualit...
# 127  [climate, environment, air quality, sensor, en...
# 159  [accessibility, wayfinding, footpath, walking,...
# 166  [pumpingstation, assets, engineering, asset, d...
# 58   [toilets, opencouncildata, ocd-toilets-1.2, ev...
# 2    [urban forest, trees, tree, forest, #urbanfore...
# 11   [parking, signs, restrictions, bay, car, trans...
# 152      [litter, assets, cleanup, debris, pollutants]
# 53   [fire, hydrant, accessibility, communitysafety...
# 56   [parking, meters, ticket, machine, car, transp...
# 212  [banner, pole, bookable, city events, promotio...
# 113  [lighting, feature lighting, assets, safemobil...
# 217  [iot, moisture, sensor, sensors, soil, tempera...
# 137               [sign, panel, accessibility, assets]
# 78   [accessibility, activities, activity, bookings...
#
#                                      c.domain_metadata  \
# 3    [{'key': 'Data-management_Source-data-update-f...
# 14   [{'key': 'Data-management_Source-data-update-f...
# 116  [{'key': 'Data-management_Source-data-update-f...
# 29   [{'key': 'Data-management_Source-data-update-f...
# 195  [{'key': 'Data-management_Source-data-update-f...
# 67   [{'key': 'Data-management_Source-data-update-f...
# 127  [{'key': 'Data-management_Source-data-update-f...
# 159  [{'key': 'Data-management_Source-data-update-f...
# 166  [{'key': 'Data-management_Source-data-update-f...
# 58   [{'key': 'Data-management_Source-data-update-f...
# 2    [{'key': 'Data-management_Source-data-update-f...
# 11   [{'key': 'Data-management_Source-data-update-f...
# 152  [{'key': 'Data-management_Source-data-update-f...
# 53   [{'key': 'Data-management_Source-data-update-f...
# 56   [{'key': 'Data-management_Source-data-update-f...
# 212  [{'key': 'Data-management_Source-data-update-f...
# 113  [{'key': 'Data-management_Source-data-update-f...
# 217  [{'key': 'Quality_Known-Issues', 'value': 'Non...
# 137  [{'key': 'Data-management_Source-data-update-f...
# 78   [{'key': 'Quality_What's-included', 'value': '...
#
#                                          permalink
# 3    https://data.melbourne.vic.gov.au/d/vh2v-4nfs
# 14   https://data.melbourne.vic.gov.au/d/8fgn-5q6t
# 116  https://data.melbourne.vic.gov.au/d/psq9-yz4x
# 29   https://data.melbourne.vic.gov.au/d/d6mv-s43h
# 195  https://data.melbourne.vic.gov.au/d/mv4n-8k4v
# 67   https://data.melbourne.vic.gov.au/d/u4vh-84j8
# 127  https://data.melbourne.vic.gov.au/d/irqv-hjr4
# 159  https://data.melbourne.vic.gov.au/d/v4zv-yqtp
# 166  https://data.melbourne.vic.gov.au/d/55z9-zqzu
# 58   https://data.melbourne.vic.gov.au/d/ru3z-44we
# 2    https://data.melbourne.vic.gov.au/d/fp38-wiyy
# 11   https://data.melbourne.vic.gov.au/d/ntht-5rk7
# 152  https://data.melbourne.vic.gov.au/d/4spx-8bh5
# 53   https://data.melbourne.vic.gov.au/d/j4qc-4tib
# 56   https://data.melbourne.vic.gov.au/d/vdsi-4gtj
# 212  https://data.melbourne.vic.gov.au/d/cm7k-9aj4
# 113  https://data.melbourne.vic.gov.au/d/4j42-79hg
# 217  https://data.melbourne.vic.gov.au/d/dxvp-runr
# 137  https://data.melbourne.vic.gov.au/d/fzjr-9nrn
# 78   https://data.melbourne.vic.gov.au/d/txcy-uafv

# %%
## 006 ##
r1 = client.get_all('vh2v-4nfs')
df_r1 = pd.DataFrame.from_dict(r1)
df_r1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   bay_id                       1022 non-null   object
#  1   st_marker_id                 1022 non-null   object
#  2   status                       1022 non-null   object
#  3   location                     1022 non-null   object
#  4   lat                          1022 non-null   object
#  5   lon                          1022 non-null   object
#  6   :@computed_region_evbi_jbp8  1022 non-null   object
# dtypes: object(7)
# memory usage: 56.0+ KB

# %%
(df_r1["status"]=="Present").sum()
# Out:
# 412

# %%
(df_r1["status"]=="Unoccupied").sum()
# Out:
# 610

# %%
## 006a function to get key info from current status read of parking sensors ##
def getCurrentPSstatus(df):
    """Check supplied df, then print and return occupied and unoccupied parking bay status

    Args:
        df (pandas dataframe): containing full or subset of current status records of parking sensors read

    Returns:
        tuple: of total number of parking bays in df, number of available and unavailable parking bays in df
    """    
    no_bays = df.shape[0]
    no_pres = (df["status"]=="Present").sum()
    no_unoc = (df["status"]=="Unoccupied").sum()
    print(f"Number of current status records of parking sensors read : {no_bays}")
    print(f"Number of current available parking bays : {no_pres} ({round((100*no_pres/no_bays),1)}% of total)")
    print(f"Number of current unavailable parking bays : {no_unoc} ({round((100*no_unoc/no_bays),1)}% of total)")
    return no_bays, no_pres, no_unoc

# %%
df_r1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   bay_id                       1022 non-null   object
#  1   st_marker_id                 1022 non-null   object
#  2   status                       1022 non-null   object
#  3   location                     1022 non-null   object
#  4   lat                          1022 non-null   object
#  5   lon                          1022 non-null   object
#  6   :@computed_region_evbi_jbp8  1022 non-null   object
# dtypes: object(7)
# memory usage: 56.0+ KB

# %%
## 006b test function above ##
getCurrentPSstatus(df_r1)
# Out:
# Number of current status records of parking sensors read : 1022
# Number of current available parking bays : 412 (40.3% of total)
# Number of current unavailable parking bays : 610 (59.7% of total)
# (1022, 412, 610)

# %%
## 007 ##
# loop to read dataset in below hours and intervals, buffering our dataset in a csv

interval = 5
hours = 1
runs = int(hours*(60/interval))
ds_id = 'vh2v-4nfs'
ds_no = "003"
ds_fname = "datasets/"+ds_no+"_"+ds_id+"__bufferred"+".csv"

for i in range(runs):
    r1 = client.get_all(ds_id)  # get snapshot of dataset using sodapy api 
    df_temp = pd.DataFrame.from_dict(r1)  # read dict to dataframe
    df_temp['db_read_time']=datetime.now()  # add timestampe column
    if i == 0:
        df_temp.to_csv(ds_fname, mode='w', header=True)  # first write
    else:
        df_temp.to_csv(ds_fname, mode='a', header=False)  # subsequent append to csv        
    print(f"run [{i}] at [{datetime.now()}]")   # print loop progress to keep track
    print(f"--> [{df_temp.bay_id.nunique()}] unique bay_ids picked up in this run")
    time.sleep(60*interval)  # sleep 15min before next read and append
# Out:
# run [0] at [2021-08-02 21:14:55.177216]
# --> [1116] unique bay_ids picked up in this run
# run [1] at [2021-08-02 21:19:57.044347]
# --> [1116] unique bay_ids picked up in this run
# run [2] at [2021-08-02 21:24:59.229583]
# --> [1116] unique bay_ids picked up in this run
# run [3] at [2021-08-02 21:30:01.112287]
# --> [1031] unique bay_ids picked up in this run
# run [4] at [2021-08-02 21:35:03.094059]
# --> [1031] unique bay_ids picked up in this run
# run [5] at [2021-08-02 21:40:05.000949]
# --> [1031] unique bay_ids picked up in this run
# run [6] at [2021-08-02 21:45:07.015876]
# --> [1116] unique bay_ids picked up in this run
# run [7] at [2021-08-02 21:50:09.549744]
# --> [1116] unique bay_ids picked up in this run
# run [8] at [2021-08-02 21:55:11.505166]
# --> [1032] unique bay_ids picked up in this run
# run [9] at [2021-08-02 22:00:13.501655]
# --> [1032] unique bay_ids picked up in this run
# run [10] at [2021-08-02 22:05:15.281852]
# --> [1116] unique bay_ids picked up in this run
# run [11] at [2021-08-02 22:10:17.493472]
# --> [1032] unique bay_ids picked up in this run

# %%
## 008 ##
df_fetched = pd.read_csv(ds_fname)
df_fetched.db_read_time = pd.to_datetime(df_fetched.db_read_time)
df_fetched.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22991 entries, 0 to 22990
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   22991 non-null  int64
#  1   bay_id                       22991 non-null  int64
#  2   st_marker_id                 22991 non-null  object
#  3   status                       22991 non-null  object
#  4   location                     22991 non-null  object
#  5   lat                          22991 non-null  float64
#  6   lon                          22991 non-null  float64
#  7   :@computed_region_evbi_jbp8  22991 non-null  int64
#  8   db_read_time                 22991 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 1.6+ MB

# %%
## 009 ##
# function to download dataset (assume json format) and save it to csv in datasets folder

def download_dataset(client,ds_no,ds_id):
    ds_fname = ds_no+"_"+ds_id+".csv"

    result = client.get_all(ds_id)  # get result of dataset using sodapy api 
    df_temp = pd.DataFrame.from_dict(result)  # read dict to dataframe
    df_temp['db_read_time']=datetime.now()  # add timestampe column
    
    timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
    df_temp.to_csv("datasets/"+ds_no+"_"+ds_id+"_dl_at__"+timestamp+".csv",
                   mode='w', header=True)  # write to csv

# %%
## 010 ##
download_dataset(client,"075","wwkr-v8s7")

# %%
## 012 ##
download_dataset(client,"056","vdsi-4gtj")

# %%
## 013 ##
# more comprehensive than code block ## 007 ##
# this code block to run for some time --> to buffer some parking sensor data to play with

import os
import time
from datetime import datetime
import pandas as pd
from sodapy import Socrata

apptoken = os.environ.get("wMEkdLbVuXIpLiCFVic1PgiZ3")
domain = "data.melbourne.vic.gov.au"
client = Socrata(domain, apptoken)

interval, hours = 15, 1
runs = int(hours*(60/interval))
ds_id, ds_no = 'vh2v-4nfs', "003"
ds_fname = os.path.join('datasets', ds_no+"_"+ds_id+"__bufferred"+".csv")
uq_fname = os.path.join('datasets', ds_no+"_"+ds_id+"__uniqueBays"+".csv")
ds_col1 = ['bay_id', 'st_marker_id', 'status', 'lat', 'lon']
ds_col2 = ['bay_id', 'st_marker_id', 'lat', 'lon', 'location']
log_fname = os.path.join('datasets', ds_no+"_"+ds_id+"__log"+".txt")
for i in range(runs):
    r1 = client.get_all(ds_id)  # get snapshot of dataset using sodapy api
    df_temp = pd.DataFrame.from_dict(r1)  # read dict to dataframe
    df_temp1 = df_temp[ds_col1]
    df_temp2 = df_temp[ds_col2]
    df_temp1['db_read_time'] = datetime.now()  # add timestampe column
    if i == 0:
        df_temp1.to_csv(ds_fname, mode='w', header=True,
                        index=False)  # first write
        df_temp2.to_csv(uq_fname, mode='w', header=True, index=False)
        o = open(log_fname,'w')
        print(f"{datetime.now()}, dataset retrieved and written to csv", file=o)
        print(f"{datetime.now()}, unique parking bays csv written", file=o)
        o.close()
    else:
        df_temp1.to_csv(ds_fname, mode='a', header=False,
                        index=False)  # subsequent append to csv
        df_temp2prev = pd.read_csv(uq_fname)
        df_temp2new = pd.concat(
            [df_temp2prev, df_temp2], axis='index').drop_duplicates()
        df_temp2new.to_csv(uq_fname, mode='w', header=True, index=False)
        o = open(log_fname,'a')
        print(f"{datetime.now()}, dataset retrieved and appended to csv", file=o)
        print(f"{datetime.now()}, unique parking bays csv updated", file=o)
        o.close()
    time.sleep(60*interval)  # sleep 15min before next read and append
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# /home/honalbert/.local/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-c823dc69a50e> in <module>
#      41         print(f"{datetime.now()}, unique parking bays csv updated", file=o)
#      42         o.close()
# ---> 43     time.sleep(60*interval)  # sleep 15min before next read and append
#
# KeyboardInterrupt:

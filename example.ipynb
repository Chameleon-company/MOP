# %% [markdown]
# # Summary Table for Open Data

# %%
import deakin 
sum_table, client= deakin.summary_table()
sum_table.sort_values(['downloadCount'], ascending=False).head(40)

sum_table
# Out:
#                                                   Name         id  \
# 0    Pedestrian Counting System - Monthly (counts p...  b2ak-trbp
# 1                    Tree canopies 2011 (Urban Forest)  y79a-us3f
# 2    Trees, with species and dimensions (Urban Forest)  fp38-wiyy
# 3                        On-street Parking Bay Sensors  vh2v-4nfs
# 4             Pay Stay zones linked to street segments  7q9g-yyvg
# ..                                                 ...        ...
# 217                              Soil Sensor Locations  dxvp-runr
# 218  Commingled recycling collected at Centre Place...  m8kf-ur3f
# 219  Commingled recycling collected at Degraves St ...  mcf9-snjr
# 220  Cardboard bales collected at Degraves St Recyc...  hisn-tyup
# 221  Social Indicators for City of Melbourne Reside...  y7km-5r6f
#
#                   updatead_At                  createAt  \
# 0    2021-07-12T01:54:34.000Z  2014-05-03T17:40:57.000Z
# 1    2020-04-05T21:46:11.000Z  2014-07-25T05:11:43.000Z
# 2    2021-07-28T16:07:07.000Z  2014-05-26T04:40:31.000Z
# 3    2021-07-29T03:03:28.000Z  2017-08-10T04:57:59.000Z
# 4    2020-02-24T02:10:34.000Z  2017-11-01T03:43:04.000Z
# ..                        ...                       ...
# 217  2021-07-28T05:40:00.000Z  2020-03-26T21:23:31.000Z
# 218  2020-02-25T02:20:09.000Z  2017-05-12T06:07:25.000Z
# 219  2020-02-25T07:05:12.000Z  2017-05-12T06:16:52.000Z
# 220  2020-02-25T07:02:03.000Z  2017-05-12T06:17:25.000Z
# 221  2020-12-15T04:39:03.000Z  2020-11-13T01:35:44.000Z
#
#                                              pageViews  \
# 0    {'page_views_last_week': 122, 'page_views_last...
# 1    {'page_views_last_week': 6, 'page_views_last_m...
# 2    {'page_views_last_week': 75, 'page_views_last_...
# 3    {'page_views_last_week': 210, 'page_views_last...
# 4    {'page_views_last_week': 62, 'page_views_last_...
# ..                                                 ...
# 217  {'page_views_last_week': 3, 'page_views_last_m...
# 218  {'page_views_last_week': 0, 'page_views_last_m...
# 219  {'page_views_last_week': 0, 'page_views_last_m...
# 220  {'page_views_last_week': 3, 'page_views_last_m...
# 221  {'page_views_last_week': 3, 'page_views_last_m...
#
#                                             attributes  downloadCount
# 0    [Month, Date_Time, Time, Sensor_ID, Day, Year,...           7388
# 1                                                   []           3178
# 2    [Common Name, Scientific Name, Year Planted, P...           6043
# 3    [bay_id, st_marker_id, status, location, locat...       12074040
# 4    [pay_stay_zone, street, between_street_2, stre...           1687
# ..                                                 ...            ...
# 217  [site_id, site_name, property_name, latitude, ...             21
# 218  [Time bin 2 spot weight checked, Total 1100 li...            750
# 219  [column 9, Number of 1100-litre bins filled, T...            793
# 220  [Estimated weight of cardboard (kg), Thursday,...            793
# 221  [FORMAT, INDICATOR, TOPIC, DESCRIPTION, RESPON...             95
#
# [222 rows x 7 columns]

# %%
'''
for each_dataset in client.datasets():
    for key_name in each_dataset['resource']:
        print(key_name,":" ,each_dataset['resource'][str(key_name)])    
    print('\n','*'*30,'\n')
'''
# Out:
# '\nfor each_dataset in client.datasets():\n    for key_name in each_dataset[\'resource\']:\n        print(key_name,":" ,each_dataset[\'resource\'][str(key_name)])    \n    print(\'\n\',\'*\'*30,\'\n\')\n'

# %%
#client.datasets()

# %%
for each_dataset in client.datasets():
#   if ['bay_id'] in (each_dataset['resource']['columns_field_name']):
    for col_name in each_dataset['resource']['columns_field_name']:
        if 'bay' in col_name:
            print(each_dataset['resource']['name'])
            print(each_dataset['resource']['columns_field_name'] )
            print('\n','*'*30,'\n')
# Out:
# On-street Parking Bay Sensors
# ['bay_id', 'st_marker_id', 'status', 'location', 'location_address', 'location_city', 'location_state', 'location_zip', 'lat', 'lon', ':@computed_region_evbi_jbp8']
#
#  ******************************
#
# On-street Car Park Bay Restrictions
# ['starttime5', 'exemption4', 'today3', 'effectiveonph5', 'starttime6', 'fromday1', 'today1', 'effectiveonph1', 'disabilityext1', 'duration5', 'bayid', 'description3', 'duration3', 'typedesc2', 'effectiveonph4', 'duration6', 'endtime1', 'exemption5', 'effectiveonph6', 'disabilityext4', 'description6', 'starttime1', 'deviceid', 'description1', 'description2', 'description4', 'typedesc3', 'disabilityext2', 'today2', 'description5', 'fromday6', 'fromday3', 'duration4', 'fromday2', 'today5', 'effectiveonph2', 'typedesc4', 'starttime2', 'starttime3', 'endtime2', 'endtime4', 'typedesc5', 'fromday4', 'fromday5', 'typedesc6', 'disabilityext3', 'endtime6', 'exemption2', 'effectiveonph3', 'disabilityext6', 'endtime5', 'typedesc1', 'exemption1', 'duration2', 'duration1', 'endtime3', 'starttime4', 'exemption6', 'today4', 'disabilityext5', 'exemption3', 'today6']
#
#  ******************************
#
# Parking bay arrivals and departures 2014
# ['bayid', 'areaname', 'sideofstreet', 'signplateid', 'sidecode', 'sidename', 'deviceid', 'streetmarker', 'durationseconds', 'inviolation', 'lkp_between_street_2_betweenstreet2', 'lkp_bay_location_betweenstreet1', 'lkp_bay_location_betweenstreet2', 'departuretime', 'lkp_between_street_1_betweenstreet1', 'arrivaltime', 'sign', 'streetname', 'streetid', 'area', 'eventid']
#
#  ******************************
#
# Parking bay arrivals and departures 2014
# ['bayid', 'areaname', 'sideofstreet', 'signplateid', 'sidecode', 'sidename', 'deviceid', 'streetmarker', 'durationseconds', 'inviolation', 'lkp_between_street_2_betweenstreet2', 'lkp_bay_location_betweenstreet1', 'lkp_bay_location_betweenstreet2', 'departuretime', 'lkp_between_street_1_betweenstreet1', 'arrivaltime', 'sign', 'streetname', 'streetid', 'area', 'eventid']
#
#  ******************************
#
# Parking bay arrivals and departures 2014
# ['bayid', 'areaname', 'sideofstreet', 'signplateid', 'sidecode', 'sidename', 'deviceid', 'streetmarker', 'durationseconds', 'inviolation', 'lkp_between_street_2_betweenstreet2', 'lkp_bay_location_betweenstreet1', 'lkp_bay_location_betweenstreet2', 'departuretime', 'lkp_between_street_1_betweenstreet1', 'arrivaltime', 'sign', 'streetname', 'streetid', 'area', 'eventid']
#
#  ******************************
#
# On-street Car Parking Sensor Data - 2019
# ['streetmarker', 'betweenstreet1id', 'streetname', 'streetid', 'areaname', 'signplateid', 'inviolation', 'sideofstreet', 'sideofstreetcode', 'deviceid', 'arrivaltime', 'departuretime', 'durationminutes', 'sign', 'vehiclepresent', 'bayid', 'sidename', 'betweenstreet2', 'betweenstreet2id', 'betweenstreet1']
#
#  ******************************
#
# On-street Car Parking Sensor Data - 2020 (Jan - May)
# ['inviolation', 'betweenstreet1', 'betweenstreet2', 'streetmarker', 'betweenstreet2id', 'arrivaltime', 'deviceid', 'departuretime', 'sign', 'sidename', 'sideofstreet', 'betweenstreet1id', 'vehiclepresent', 'signplateid', 'streetid', 'durationminutes', 'bayid', 'streetname', 'areaname']
#
#  ******************************
#
# On-street Car Parking Sensor Data - 2018
# ['betweenstreet1id', 'durationminutes', 'departuretime', 'sign', 'streetname', 'betweenstreet1', 'bayid', 'arrivaltime', 'streetid', 'betweenstreet2id', 'betweenstreet2', 'areaname', 'streetmarker', 'sidename', 'signplateid', 'deviceid', 'sideofstreet', 'inviolation', 'vehiclepresent']
#
#  ******************************

# %%
'''
results = client.get_all('b2ak-trbp')
results_df = pd.DataFrame.from_records(results)
results_df
'''
# Out:
# "\nresults = client.get_all('b2ak-trbp')\nresults_df = pd.DataFrame.from_records(results)\nresults_df\n"

# %%
results = client.get_all('vh2v-4nfs')
results_df = pd.DataFrame.from_records(results)
results_df

# %% [markdown]
# ## Parking Dataset with their unique identifiers

# %%
dataset_name=[]
dataset_id = []
for a in client.datasets():
    if a['resource']['name'].find("On-street") != -1:
        #print(a['resource']['name'],a['resource']['id'])
        dataset_name.append(a['resource']['name'])
        dataset_id.append(a['resource']['id'])

dataset_name[3:]
dataset_id[3:]
parking_dataset =pd.DataFrame({'name':dataset_name[3:],
            'id':dataset_id[3:]})
parking_dataset = parking_dataset.drop(index = 1)
parking_dataset
# Out:
#                                                  name         id
# 0            On-street Car Parking Sensor Data - 2017  u9sa-j86i
# 2            On-street Car Parking Sensor Data - 2016  dj7e-rdx9
# 3            On-street Car Parking Sensor Data - 2019  7pgd-bdf2
# 4   On-street Car Parking Sensor Data - 2020 (Jan ...  4n3a-s6rn
# 5            On-street Car Parking Sensor Data - 2014  t6hb-9uf2
# 6            On-street Car Parking Sensor Data - 2015  apua-t2tb
# 7            On-street Car Parking Sensor Data - 2011  vkxi-k7ps
# 8            On-street Car Parking Sensor Data - 2018  5532-ig9r
# 9            On-street Car Parking Sensor Data - 2012  vbe9-m4tk
# 10           On-street Car Parking Sensor Data - 2013  7jq6-k9kf

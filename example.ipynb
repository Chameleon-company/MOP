# %% [markdown]
# # Summary Table for Open Data

# %%
import deakin 
sum_table, client= deakin.summary_table()
sum_table.sort_values(['downloadCount'], ascending=False).head(40)

sum_table
# Out:
#                                                   Name         id  \
# 0    Pedestrian Counting System - Monthly (counts p...  b2ak-trbp
# 1                    Tree canopies 2011 (Urban Forest)  y79a-us3f
# 2    Trees, with species and dimensions (Urban Forest)  fp38-wiyy
# 3                        On-street Parking Bay Sensors  vh2v-4nfs
# 4             Pay Stay zones linked to street segments  7q9g-yyvg
# ..                                                 ...        ...
# 217                              Soil Sensor Locations  dxvp-runr
# 218  Commingled recycling collected at Centre Place...  m8kf-ur3f
# 219  Commingled recycling collected at Degraves St ...  mcf9-snjr
# 220  Cardboard bales collected at Degraves St Recyc...  hisn-tyup
# 221  Social Indicators for City of Melbourne Reside...  y7km-5r6f
#
#                   updatead_At                  createAt  \
# 0    2021-07-12T01:54:34.000Z  2014-05-03T17:40:57.000Z
# 1    2020-04-05T21:46:11.000Z  2014-07-25T05:11:43.000Z
# ...

# %%
#for i in client.datasets():
#    print(i)


for each_dataset in client.datasets():
    for key_name in each_dataset['resource']:
        print(key_name,":" ,each_dataset['resource'][str(key_name)])
        
    print('\n','*'*30,'\n')
# Out:
# name : Pedestrian Counting System - Monthly (counts per hour)
# id : b2ak-trbp
# parent_fxf : []
# description : This dataset contains hourly pedestrian counts since 2009 from pedestrian sensor devices located across the city. The data is updated on a monthly basis and can be used to determine variations in pedestrian activity throughout the day.
# <p>The sensor_id column can be used to merge the data with the <a href="https://data.melbourne.vic.gov.au/Transport-Movement/Pedestrian-Counting-System-Sensor-Locations/h57g-5234">Pedestrian Counting System - Sensor Locations</a> dataset which details the location, status and directional readings of sensors. Any changes to sensor locations are important to consider when analysing and interpreting pedestrian counts over time.
# <p><b>Importants notes about this dataset:</b>
# <br>•	Where no pedestrians have passed underneath a sensor during an hour, a count of zero will be shown for the sensor for that hour.
# ...

# %%
results = client.get_all('vh2v-4nfs')
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
#      bay_id st_marker_id      status  \
# 0      3275        5834E  Unoccupied
# 1      8128       15156N  Unoccupied
# 2      4114        C6380  Unoccupied
# 3      3500        6614N  Unoccupied
# 4      6030       13071S  Unoccupied
# ...     ...          ...         ...
# 1060   3719        7722N     Present
# 1061   3019        5100E  Unoccupied
# 1062   1471        1775S  Unoccupied
# 1063   3727        7762N  Unoccupied
# 1064   2999        5048E     Present
#
#                                                location                  lat  \
# 0     {'latitude': '-37.806668087276925', 'longitude...  -37.806668087276925
# 1     {'latitude': '-37.816650137434166', 'longitude...  -37.816650137434166
# 2     {'latitude': '-37.804008866097604', 'longitude...  -37.804008866097604
# 3     {'latitude': '-37.808335785802356', 'longitude...  -37.808335785802356
# 4     {'latitude': '-37.821322287092045', 'longitude...  -37.821322287092045
# ...

# %% [markdown]
# ## Parking Dataset with their unique identifiers

# %%
dataset_name=[]
dataset_id = []
for a in client.datasets():
    if a['resource']['name'].find("On-street") != -1:
        #print(a['resource']['name'],a['resource']['id'])
        dataset_name.append(a['resource']['name'])
        dataset_id.append(a['resource']['id'])

dataset_name[3:]
dataset_id[3:]
parking_dataset =pd.DataFrame({'name':dataset_name[3:],
            'id':dataset_id[3:]})
parking_dataset = parking_dataset.drop(index = 1)
parking_dataset
# Out:
#                                                  name         id
# 0            On-street Car Parking Sensor Data - 2017  u9sa-j86i
# 2            On-street Car Parking Sensor Data - 2016  dj7e-rdx9
# 3            On-street Car Parking Sensor Data - 2019  7pgd-bdf2
# 4   On-street Car Parking Sensor Data - 2020 (Jan ...  4n3a-s6rn
# 5            On-street Car Parking Sensor Data - 2014  t6hb-9uf2
# 6            On-street Car Parking Sensor Data - 2015  apua-t2tb
# 7            On-street Car Parking Sensor Data - 2011  vkxi-k7ps
# 8            On-street Car Parking Sensor Data - 2018  5532-ig9r
# 9            On-street Car Parking Sensor Data - 2012  vbe9-m4tk
# 10           On-street Car Parking Sensor Data - 2013  7jq6-k9kf

# %%
parking_dataset.to_csv('historic_parking.csv', index=False)

# %% [markdown]
# # Summary Table for Open Data

# %%
import deakin 
sum_table, client= deakin.summary_table()
sum_table.sort_values(['downloadCount'], ascending=False).head(40)
# Out:
#                                                   Name         id  \
# 41                                           Postcodes  m7yp-p495
# 3                        On-street Parking Bay Sensors  vh2v-4nfs
# 51                                        Street names  2x56-ai8r
# 30   Small Areas for Census of Land Use and Employm...  gei8-3w86
# 47                                      Road corridors  9mdh-8yau
# 106                             City Circle tram stops  dh3m-ckxm
# 95              Former lakes and wetlands in Melbourne  n6sz-6nb6
# 157                    Soil textures at various depths  svux-bada
# 94                            Garbage collection zones  dmpt-2xdw
# 65                                  Municipal boundary  ck33-yh8z
# 128                          Venues for event bookings  84bf-dihi
# 133          Former creeks in Melbourne (Urban Forest)  rpdm-je7s
# 96                              City Circle tram route  nmnx-3ct3
# 26                   Soil types by area (Urban Forest)  t3zn-qgfx
# 71   Tree planting zone schedules, with years (Urba...  jzfa-q3k3
# 23   Blocks for Census of Land Use and Employment (...  aia8-ryiq
# 143     Parking restrictions (southeast CBD only) 2014  xgce-vkbh
# 99          Water flow routes over land (Urban Forest)  6yxs-smdz
# 42                    Laneways with greening potential  s8dq-xd4g
# 121                                         Taxi Ranks  grmi-2ew3
# 179                                Urban renewal areas  24vx-7gkg
# 147                              Syringe bin locations  96gt-j9ix
# 16                                 Property boundaries  e56b-j9mj
# 66                                         Tram tracks  wqka-kyhz
# 97                                         Playgrounds  rwbd-626w
# 129                                  Dog Walking Zones  vzb2-a2kz
# 70                                           Bus stops  ss79-v558
# 138                          Outdoor non-smoking zones  23k2-cnm2
# 15               Development Activity Model Footprints  def8-4wbt
# 199  Block level energy consumption (modelled on bu...  xy7t-cwm2
# 43   Metro Train Stations with Accessibility Inform...  mgkp-67ad
# 77   Bicycle routes, including informal, on-road an...  24aw-nd3i
# 182           Mahlstedt's fire plans of Melbourne 1888  rqdu-ieaj
# 11                 On-street Car Park Bay Restrictions  ntht-5rk7
# 210  Block level energy consumption (modelled on bu...  hfm2-46au
# 211  Block level energy consumption (modelled on bu...  erbg-hj42
# 36   Rooftops with environmental retrofitting oppor...  3927-sgfc
# 148  Property level energy consumption (modelled on...  fyes-zqbt
# 17                                    Street addresses  a7rp-xtya
# 28                              Building outlines 2015  pv8y-ihee
#
#                   updatead_At                  createAt  \
# 41   2020-02-25T02:19:56.000Z  2014-06-26T06:28:18.000Z
# 3    2021-07-27T16:31:41.000Z  2017-08-10T04:57:59.000Z
# 51   2021-07-26T16:45:18.000Z  2015-04-14T04:36:39.000Z
# 30   2020-02-24T02:09:59.000Z  2014-05-02T08:02:19.000Z
# 47   2021-07-26T16:43:51.000Z  2014-06-26T06:31:25.000Z
# 106  2020-04-05T21:42:05.000Z  2014-06-26T05:24:08.000Z
# 95   2020-02-24T02:10:11.000Z  2014-07-09T05:04:14.000Z
# 157  {'page_views_last_week': 2, 'page_views_last_m...
# 94   {'page_views_last_week': 2, 'page_views_last_m...
# 65   {'page_views_last_week': 26, 'page_views_last_...
# 128  {'page_views_last_week': 1, 'page_views_last_m...
# 133  {'page_views_last_week': 3, 'page_views_last_m...
# 96   {'page_views_last_week': 1, 'page_views_last_m...
# 26   {'page_views_last_week': 31, 'page_views_last_...
# 71   {'page_views_last_week': 3, 'page_views_last_m...
# 23   {'page_views_last_week': 54, 'page_views_last_...
# 143  {'page_views_last_week': 6, 'page_views_last_m...
# 99   {'page_views_last_week': 5, 'page_views_last_m...
# 42   {'page_views_last_week': 3, 'page_views_last_m...
# 121  {'page_views_last_week': 9, 'page_views_last_m...
# 179  {'page_views_last_week': 12, 'page_views_last_...
# 147  {'page_views_last_week': 1, 'page_views_last_m...
# 16   {'page_views_last_week': 31, 'page_views_last_...
# 66   {'page_views_last_week': 6, 'page_views_last_m...
# 97   {'page_views_last_week': 10, 'page_views_last_...
# 129  {'page_views_last_week': 4, 'page_views_last_m...
# 70   {'page_views_last_week': 15, 'page_views_last_...
# 138  {'page_views_last_week': 1, 'page_views_last_m...
# 15   {'page_views_last_week': 30, 'page_views_last_...
# 199  {'page_views_last_week': 12, 'page_views_last_...
# 43   {'page_views_last_week': 19, 'page_views_last_...
# 77   {'page_views_last_week': 9, 'page_views_last_m...
# 182  {'page_views_last_week': 3, 'page_views_last_m...
# 11   {'page_views_last_week': 53, 'page_views_last_...
# 210  {'page_views_last_week': 1, 'page_views_last_m...
# 211  {'page_views_last_week': 1, 'page_views_last_m...
# 36   {'page_views_last_week': 30, 'page_views_last_...
# 148  {'page_views_last_week': 1, 'page_views_last_m...
# 17   {'page_views_last_week': 62, 'page_views_last_...
# 28   {'page_views_last_week': 25, 'page_views_last_...
#
#                                             attributes  downloadCount
# 41                                                  []       13530346
# 3    [bay_id, st_marker_id, status, location, locat...       12073971
# 51                                                  []        9808179
# 30                                                  []        7362378
# 47                                                  []        7206912
# 106                                                 []        6644363
# 95                                                  []        5564262
# 157                                                 []        5415168
# 94                                                  []        5049596
# 65                                                  []        5013334
# 128                                                 []        4851824
# 133                                                 []        4808644
# 96                                                  []        4551653
# 26                                                  []        3474376
# 71                                                  []        3404400
# 23                                                  []        3197896
# 143                                                 []        3150728
# 99                                                  []        3135136
# 42                                                  []        2971982
# 121                                                 []        2280595
# 179                                                 []        2269660
# 147                                                 []        2229339
# 16                                                  []        2212262
# 66                                                  []        1820910
# 97                                                  []        1726860
# 129                                                 []        1699963
# 70                                                  []        1647126
# 138                                                 []        1502235
# 15                                                  []        1007540
# 199                                                 []         880407
# 43                                                  []         721680
# 77                                                  []         709262
# 182                                                 []         639314
# 11   [BayID, DeviceID, Description1, Description2, ...         545444
# 210                                                 []         537596
# 211                                                 []         526304
# 36                                                  []         476599
# 148                                                 []         295872
# 17                                                  []         163068
# 28                                                  []         160697

# %%
results = client.get_all('vh2v-4nfs')
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
#      bay_id st_marker_id      status  \
# 0      3275        5834E  Unoccupied
# 1      8128       15156N  Unoccupied
# 2      4114        C6380  Unoccupied
# 3      3500        6614N  Unoccupied
# 4      6030       13071S  Unoccupied
# ...     ...          ...         ...
# 1060   3719        7722N     Present
# 1061   3019        5100E  Unoccupied
# 1062   1471        1775S  Unoccupied
# 1063   3727        7762N  Unoccupied
# 1064   2999        5048E     Present
#
#                                                location                  lat  \
# 0     {'latitude': '-37.806668087276925', 'longitude...  -37.806668087276925
# 1     {'latitude': '-37.816650137434166', 'longitude...  -37.816650137434166
# 2     {'latitude': '-37.804008866097604', 'longitude...  -37.804008866097604
# 3     {'latitude': '-37.808335785802356', 'longitude...  -37.808335785802356
# 4     {'latitude': '-37.821322287092045', 'longitude...  -37.821322287092045
# ...                                                 ...                  ...
# 1060  {'latitude': '-37.8033264017554', 'longitude':...    -37.8033264017554
# 1061  {'latitude': '-37.804378178842995', 'longitude...  -37.804378178842995
# 1062  {'latitude': '-37.8167541660727', 'longitude':...    -37.8167541660727
# 1063  {'latitude': '-37.80254076503344', 'longitude'...   -37.80254076503344
# 1064  {'latitude': '-37.805320727736856', 'longitude...  -37.805320727736856
#
#                      lon :@computed_region_evbi_jbp8
# 0      144.9535383082356                           1
# 1     144.98130396822356                           1
# 2     144.95095945647938                           1
# 3      144.9594960648111                           1
# 4      144.9438011890341                           1
# ...                  ...                         ...
# 1060  144.95290410890726                           1
# 1061   144.9577120543801                           1
# 1062  144.96609310265694                           1
# 1063   144.9458218122118                           1
# 1064  144.95814372075984                           1
#
# [1065 rows x 7 columns]

# %% [markdown]
# ## Parking Dataset with their unique identifiers

# %%
dataset_name=[]
dataset_id = []
for a in client.datasets():
    if a['resource']['name'].find("On-street") != -1:
        #print(a['resource']['name'],a['resource']['id'])
        dataset_name.append(a['resource']['name'])
        dataset_id.append(a['resource']['id'])

dataset_name[3:]
dataset_id[3:]
parking_dataset =pd.DataFrame({'name':dataset_name[3:],
            'id':dataset_id[3:]})
parking_dataset = parking_dataset.drop(index = 1)
parking_dataset
# Out:
#                                                  name         id
# 0            On-street Car Parking Sensor Data - 2017  u9sa-j86i
# 2            On-street Car Parking Sensor Data - 2016  dj7e-rdx9
# 3            On-street Car Parking Sensor Data - 2019  7pgd-bdf2
# 4   On-street Car Parking Sensor Data - 2020 (Jan ...  4n3a-s6rn
# 5            On-street Car Parking Sensor Data - 2014  t6hb-9uf2
# 6            On-street Car Parking Sensor Data - 2015  apua-t2tb
# 7            On-street Car Parking Sensor Data - 2011  vkxi-k7ps
# 8            On-street Car Parking Sensor Data - 2018  5532-ig9r
# 9            On-street Car Parking Sensor Data - 2012  vbe9-m4tk
# 10           On-street Car Parking Sensor Data - 2013  7jq6-k9kf
